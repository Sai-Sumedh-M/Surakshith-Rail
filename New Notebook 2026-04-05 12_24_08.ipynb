# %%
# Show how risk has evolved — Delta time travel
spark.sql("DESCRIBE HISTORY workspace.default.risk_scores").show(10, truncate=False)

# %%
spark.table("workspace.default.running_history").show(5)
spark.table("workspace.default.risk_scores").show(5)
spark.table("weather_history").show(5)

# %%
tables = [
    "workspace.default.running_history",
    "workspace.default.stations_cleaned", 
    "workspace.default.incidents_by_zone",
    "workspace.default.features_per_segment",
    "workspace.default.risk_scores",
]
for t in tables:
    count = spark.table(t).count()
    print(f"✅ {t} — {count} rows")
